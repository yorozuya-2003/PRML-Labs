# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# # Problem-1
#
# ---

# %% [markdown]
# **Problem-1 (a)**
#
#
#
# ---

# %%
file = pd.read_csv('/content/drive/MyDrive/PRML_Lab/Lab_1/demo.csv')

# %%
file
# Out:
#                             Data
# 0                    Hello World
# 1                   I am Tanish.
# 2  This is PRML Lab Assignment-1
# 3                        Thanks!

# %%
file.Data.tolist()
# Out:
# ['Hello World', 'I am Tanish.', 'This is PRML Lab Assignment-1', 'Thanks!']

# %% [markdown]
# **Problem-1 (b)**
#
# ---

# %%
user_input = input()
# user_input = 35
num_input = int(user_input)
print('Type of user input changed from', type(user_input), 'to', type(num_input))
# Out:
# 35
# Type of user input changed from <class 'str'> to <class 'int'>

# %% [markdown]
# **Problem-1 (c)**
#
# ---

# %%
from datetime import datetime

demo_string = '11/18/03 12:00:00'
demo_string_to_datetime = datetime.strptime(demo_string, '%m/%d/%y %H:%M:%S')

print(type(demo_string), 'changed to', type(demo_string_to_datetime))
print(demo_string_to_datetime)
# Out:
# <class 'str'> changed to <class 'datetime.datetime'>
# 2003-11-18 12:00:00

# %% [markdown]
# **Problem-1 (d)**
#
# ---

# %%
# call external commands in python
import os
os.system("dir *.md")
# Out:
# 512

# %% [markdown]
# **Problem-1 (e)**
#
# ---

# %%
demo_list = [1, 2, 3, 2, 2, 4]
print('count of 2 in list:', demo_list.count(2))
# Out:
# count of 2 in list: 3

# %% [markdown]
# **Problem-1 (f)**
#
# ---

# %%
demo_list = [[1, 2], [1, [2, 3]], [1 , 3]]
flattened_list = []

def flatten(l, index):
  if(type(l[index]) != list):
    flattened_list.append(l[index])
  else:
    for i in range(len(l[index])):
      flatten(l[index], i)

for i in range(len(demo_list)):
  flatten(demo_list, i)
    
print('original list:', demo_list)
print('flattened list:', flattened_list)
# Out:
# original list: [[1, 2], [1, [2, 3]], [1, 3]]
# flattened list: [1, 2, 1, 2, 3, 1, 3]

# %% [markdown]
# **Problem-1 (g)**
#
# ---

# %%
d1 = {'hello' : 'world', 'tanish' : 'pagaria'}
d2 = {1 : 2, 3 : 4}
d3 = {}
for key in d1:
  d3[key] = d1[key]

for key in d2:
  d3[key] = d2[key]

print(d3)
# Out:
# {'hello': 'world', 'tanish': 'pagaria', 1: 2, 3: 4}

# %% [markdown]
# **Problem-1 (h)**
#
# ---

# %%
demo_list = [1, 2, 3, 4, 4, 5, 6, 6, 7, 1, 2, 3]
new_list = []
for item in demo_list:
  if item not in new_list:
    new_list.append(item)

print(new_list)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# **Problem-1 (i)**
#
# ---

# %%
demo_dict = {'hello' : 'world', 'tanish' : 'pagaria'}
demo_key1 = 'tanish'
demo_key2 = 1

if demo_key1 in demo_dict:
  print('key-1 is present in dictionary.')
else:
  print('key-1 is not present in dictionary.')
if demo_key2 in demo_dict:
  print('key-2 is present in dictionary.')
else:
  print('key-2 is not present in dictionary.')
# Out:
# key-1 is present in dictionary.
# key-2 is not present in dictionary.

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# # Problem-2
#
# ---

# %%
mat1 = np.array([[9, 2, 1], [4, 2, 2], [8, 2, 1]])
mat2 = np.array([[8, 6, 1], [9, 6, 9], [9, 4, 3]])

# %% [markdown]
# **Problem-2 (a)**
#
# ---

# %%
print('first row of first matrix:', mat1[0])
# Out:
# first row of first matrix: [9 2 1]

# %% [markdown]
# **Problem-2 (b)**
#
# ---

# %%
print('second column of second matrix:', mat2.T[1])
# Out:
# second column of second matrix: [6 6 4]

# %% [markdown]
# **Problem-2 (c)**
#
# ---

# %%
print('matrix multiplication:-\n', mat1 @ mat2)
# Out:
# matrix multiplication:-
#  [[99 70 30]
#  [68 44 28]
#  [91 64 29]]

# %% [markdown]
# **Problem-2 (d)**
#
# ---

# %%
print('element-wise multiplication:-\n', np.multiply(mat1, mat2))
# Out:
# element-wise multiplication:-
#  [[72 12  1]
#  [36 12 18]
#  [72  8  3]]

# %% [markdown]
# **Problem-2 (e)**
#
# ---

# %%
print('dot product between each column of first matrix and each column of second matrix:', mat1.T @ mat2.T)
# Out:
# dot product between each column of first matrix and each column of second matrix: [[104 177 121]
#  [ 30  48  32]
#  [ 21  30  20]]

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# # Problem-3
#
# ---

# %%
df = pd.read_csv('/content/drive/MyDrive/PRML_Lab/Lab_1/Cars93.csv')

# %%
df
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8        25
# 1         Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2          Audi       90  Compact       25.9   29.1       32.3        20
# 3          Audi      100  Midsize       30.8   37.7       44.6        19
# 4           BMW     535i  Midsize       23.7   30.0       36.2        22
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91        Volvo      240  Compact       21.8   22.7       23.5        21
# 92        Volvo      850  Midsize       24.8   26.7       28.5        20
#
#     MPG.highway             AirBags DriveTrain  ... Fuel.tank.capacity  \
# 0            31                None      Front  ...               13.2
# 1            25  Driver & Passenger      Front  ...               18.0
# 2            26         Driver only      Front  ...               16.9
# 3            26  Driver & Passenger      Front  ...               21.1
# 4            30         Driver only       Rear  ...               21.1
# ..          ...                 ...        ...  ...                ...
# 88           21                None      Front  ...               21.1
# 89           30                None      Front  ...               18.5
# 90           25                None      Front  ...               18.5
# 91           28         Driver only       Rear  ...               15.8
# 92           28  Driver & Passenger      Front  ...               19.3
#
#     Passengers  Length  Wheelbase  Width Turn.circle  Rear.seat.room  \
# 0            5     177        102     68          37            26.5
# 1            5     195        115     71          38            30.0
# 2            5     180        102     67          37            28.0
# 3            6     193        106     70          37            31.0
# 4            4     186        109     69          39            27.0
# ..         ...     ...        ...    ...         ...             ...
# 88           7     187        115     72          38            34.0
# 89           5     180        103     67          35            31.5
# 90           4     159         97     66          36            26.0
# 91           5     190        104     67          37            29.5
# 92           5     184        105     69          38            30.0
#
#     Luggage.room  Weight   Origin
# 0           11.0    2705  non-USA
# 1           15.0    3560  non-USA
# 2           14.0    3375  non-USA
# 3           17.0    3405  non-USA
# 4           13.0    3640  non-USA
# ..           ...     ...      ...
# 88           NaN    3960  non-USA
# 89          14.0    2985  non-USA
# 90          15.0    2810  non-USA
# 91          14.0    2985  non-USA
# 92          15.0    3245  non-USA
#
# [93 rows x 26 columns]

# %% [markdown]
# **Problem-3 (i)**
#
# ---

# %%
# (a) model => ordinal scale
# (b) type => nominal scale
# (c) max. price => ratio scale
# (d) airbags => nominal scale

# %%
df.dtypes
# Out:
# Manufacturer           object
# Model                  object
# Type                   object
# Min.Price             float64
# Price                 float64
# Max.Price             float64
# MPG.city                int64
# MPG.highway             int64
# AirBags                object
# DriveTrain             object
# Cylinders              object
# EngineSize            float64
# Horsepower              int64
# RPM                     int64
# Rev.per.mile            int64
# Man.trans.avail        object
# Fuel.tank.capacity    float64
# Passengers              int64
# Length                  int64
# Wheelbase               int64
# Width                   int64
# Turn.circle             int64
# Rear.seat.room        float64
# Luggage.room          float64
# Weight                  int64
# Origin                 object
# dtype: object

# %%
def assign_scale(dataframe):
  ordinal = []
  nominal = []
  ratio = []
  interval = []

  col_list = df.columns.tolist()
  
  for col in col_list:
    if(df.dtypes[col] == 'object'):
      col_set = set()
      for each in df[col]:
        col_set.add(each)

      if len(col_set) < 10:
        nominal.append(col)
      else:
        ordinal.append(col)

    else:
      if df.dtypes[col] == int:
        interval.append(col)
      else:
        ratio.append(col)

  print('nominal:', nominal)
  print('ordinal:', ordinal)
  print('interval:', interval)
  print('ratio:', ratio)

assign_scale(df)
# Out:
# nominal: ['Type', 'AirBags', 'DriveTrain', 'Cylinders', 'Man.trans.avail', 'Origin']
# ordinal: ['Manufacturer', 'Model']
# interval: ['MPG.city', 'MPG.highway', 'Horsepower', 'RPM', 'Rev.per.mile', 'Passengers', 'Length', 'Wheelbase', 'Width', 'Turn.circle', 'Weight']
# ratio: ['Min.Price', 'Price', 'Max.Price', 'EngineSize', 'Fuel.tank.capacity', 'Rear.seat.room', 'Luggage.room']

# %% [markdown]
# **Problem-3 (ii)**
#
# ---

# %%
df = df.dropna(axis = 0)

# %%
df
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8        25
# 1         Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2          Audi       90  Compact       25.9   29.1       32.3        20
# 3          Audi      100  Midsize       30.8   37.7       44.6        19
# 4           BMW     535i  Midsize       23.7   30.0       36.2        22
# ..          ...      ...      ...        ...    ...        ...       ...
# 87   Volkswagen      Fox    Small        8.7    9.1        9.5        25
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91        Volvo      240  Compact       21.8   22.7       23.5        21
# 92        Volvo      850  Midsize       24.8   26.7       28.5        20
#
#     MPG.highway             AirBags DriveTrain  ... Fuel.tank.capacity  \
# 0            31                None      Front  ...               13.2
# 1            25  Driver & Passenger      Front  ...               18.0
# 2            26         Driver only      Front  ...               16.9
# 3            26  Driver & Passenger      Front  ...               21.1
# 4            30         Driver only       Rear  ...               21.1
# ..          ...                 ...        ...  ...                ...
# 87           33                None      Front  ...               12.4
# 89           30                None      Front  ...               18.5
# 90           25                None      Front  ...               18.5
# 91           28         Driver only       Rear  ...               15.8
# 92           28  Driver & Passenger      Front  ...               19.3
#
#     Passengers  Length  Wheelbase  Width Turn.circle  Rear.seat.room  \
# 0            5     177        102     68          37            26.5
# 1            5     195        115     71          38            30.0
# 2            5     180        102     67          37            28.0
# 3            6     193        106     70          37            31.0
# 4            4     186        109     69          39            27.0
# ..         ...     ...        ...    ...         ...             ...
# 87           4     163         93     63          34            26.0
# 89           5     180        103     67          35            31.5
# 90           4     159         97     66          36            26.0
# 91           5     190        104     67          37            29.5
# 92           5     184        105     69          38            30.0
#
#     Luggage.room  Weight   Origin
# 0           11.0    2705  non-USA
# 1           15.0    3560  non-USA
# 2           14.0    3375  non-USA
# 3           17.0    3405  non-USA
# 4           13.0    3640  non-USA
# ..           ...     ...      ...
# 87          10.0    2240  non-USA
# 89          14.0    2985  non-USA
# 90          15.0    2810  non-USA
# 91          14.0    2985  non-USA
# 92          15.0    3245  non-USA
#
# [82 rows x 26 columns]

# %% [markdown]
# **Problem-3 (iii)**
#
# ---

# %%
col_list = df.columns.tolist()
num_col = len(col_list)

# %%
index_label_list = df.index.values.tolist()
# index_label_list

# %%
dtype_list = []
col_list = df.columns.tolist()
for col in col_list:
  if str(df[col][0]).isnumeric():
    dtype_list.append(int)
  else:
    dtype_list.append(type(df[col][0]))

# dtype_list

# %%
rows_to_be_removed = []
for row in range(len(df)):
  for col in range(num_col):
    if dtype_list[col] == str:
      if str(df.iloc[row, col]).isnumeric() and row not in rows_to_be_removed:
        rows_to_be_removed.append(row)

rows_to_be_removed
# Out:
# [2, 3, 47, 49, 68, 80, 81]

# %%
for r in range(len(rows_to_be_removed)):
    rows_to_be_removed[r] = index_label_list[rows_to_be_removed[r]]

rows_to_be_removed
# Out:
# [2, 3, 52, 54, 77, 91, 92]

# %%
df = df.drop(rows_to_be_removed)

# %%
df
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8        25
# 1         Acura   Legend  Midsize       29.2   33.9       38.7        18
# 4           BMW     535i  Midsize       23.7   30.0       36.2        22
# 5         Buick  Century  Midsize       14.2   15.7       17.3        22
# 6         Buick  LeSabre    Large       19.9   20.8       21.7        19
# ..          ...      ...      ...        ...    ...        ...       ...
# 84       Toyota   Celica   Sporty       14.2   18.4       22.6        25
# 85       Toyota    Camry  Midsize       15.2   18.2       21.2        22
# 87   Volkswagen      Fox    Small        8.7    9.1        9.5        25
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
#
#     MPG.highway             AirBags DriveTrain  ... Fuel.tank.capacity  \
# 0            31                None      Front  ...               13.2
# 1            25  Driver & Passenger      Front  ...               18.0
# 4            30         Driver only       Rear  ...               21.1
# 5            31         Driver only      Front  ...               16.4
# 6            28         Driver only      Front  ...               18.0
# ..          ...                 ...        ...  ...                ...
# 84           32         Driver only      Front  ...               15.9
# 85           29         Driver only      Front  ...               18.5
# 87           33                None      Front  ...               12.4
# 89           30                None      Front  ...               18.5
# 90           25                None      Front  ...               18.5
#
#     Passengers  Length  Wheelbase  Width Turn.circle  Rear.seat.room  \
# 0            5     177        102     68          37            26.5
# 1            5     195        115     71          38            30.0
# 4            4     186        109     69          39            27.0
# 5            6     189        105     69          41            28.0
# 6            6     200        111     74          42            30.5
# ..         ...     ...        ...    ...         ...             ...
# 84           4     174         99     69          39            23.0
# 85           5     188        103     70          38            28.5
# 87           4     163         93     63          34            26.0
# 89           5     180        103     67          35            31.5
# 90           4     159         97     66          36            26.0
#
#     Luggage.room  Weight   Origin
# 0           11.0    2705  non-USA
# 1           15.0    3560  non-USA
# 4           13.0    3640  non-USA
# 5           16.0    2880      USA
# 6           17.0    3470      USA
# ..           ...     ...      ...
# 84          13.0    2950  non-USA
# 85          15.0    3030  non-USA
# 87          10.0    2240  non-USA
# 89          14.0    2985  non-USA
# 90          15.0    2810  non-USA
#
# [75 rows x 26 columns]

# %% [markdown]
# **Problem-3 (iv)**
#
# ---

# %%
df.dtypes
# Out:
# Manufacturer           object
# Model                  object
# Type                   object
# Min.Price             float64
# Price                 float64
# Max.Price             float64
# MPG.city                int64
# MPG.highway             int64
# AirBags                object
# DriveTrain             object
# Cylinders              object
# EngineSize            float64
# Horsepower              int64
# RPM                     int64
# Rev.per.mile            int64
# Man.trans.avail        object
# Fuel.tank.capacity    float64
# Passengers              int64
# Length                  int64
# Wheelbase               int64
# Width                   int64
# Turn.circle             int64
# Rear.seat.room        float64
# Luggage.room          float64
# Weight                  int64
# Origin                 object
# dtype: object

# %%
obj_list = []

for col in col_list:
  if df.dtypes[col] == 'object':
    obj_list.append(col)

# %%
obj_list
# Out:
# ['Manufacturer',
#  'Model',
#  'Type',
#  'AirBags',
#  'DriveTrain',
#  'Cylinders',
#  'Man.trans.avail',
#  'Origin']

# %%
df[obj_list] = df[obj_list].astype('category')
for col in obj_list:
  df[col] = df[col].cat.codes
df
# Out:
#     Manufacturer  Model  Type  Min.Price  Price  Max.Price  MPG.city  \
# 0              0     36     3       12.9   15.9       18.8        25
# 1              0     43     2       29.2   33.9       38.7        18
# 4              1      2     2       23.7   30.0       36.2        22
# 5              2     13     2       14.2   15.7       17.3        22
# 6              2     41     1       19.9   20.8       21.7        19
# ..           ...    ...   ...        ...    ...        ...       ...
# 84            27     12     4       14.2   18.4       22.6        25
# 85            27      8     2       15.2   18.2       21.2        22
# 87            28     33     3        8.7    9.1        9.5        25
# 89            28     50     0       17.6   20.0       22.4        21
# 90            28     18     4       22.9   23.3       23.7        18
#
#     MPG.highway  AirBags  DriveTrain  ...  Fuel.tank.capacity  Passengers  \
# 0            31        2           1  ...                13.2           5
# 1            25        0           1  ...                18.0           5
# 4            30        1           2  ...                21.1           4
# 5            31        1           1  ...                16.4           6
# 6            28        1           1  ...                18.0           6
# ..          ...      ...         ...  ...                 ...         ...
# 84           32        1           1  ...                15.9           4
# 85           29        1           1  ...                18.5           5
# 87           33        2           1  ...                12.4           4
# 89           30        2           1  ...                18.5           5
# 90           25        2           1  ...                18.5           4
#
#     Length  Wheelbase  Width  Turn.circle  Rear.seat.room  Luggage.room  \
# 0      177        102     68           37            26.5          11.0
# 1      195        115     71           38            30.0          15.0
# 4      186        109     69           39            27.0          13.0
# 5      189        105     69           41            28.0          16.0
# 6      200        111     74           42            30.5          17.0
# ..     ...        ...    ...          ...             ...           ...
# 84     174         99     69           39            23.0          13.0
# 85     188        103     70           38            28.5          15.0
# 87     163         93     63           34            26.0          10.0
# 89     180        103     67           35            31.5          14.0
# 90     159         97     66           36            26.0          15.0
#
#     Weight  Origin
# 0     2705       1
# 1     3560       1
# 4     3640       1
# 5     2880       0
# 6     3470       0
# ..     ...     ...
# 84    2950       1
# 85    3030       1
# 87    2240       1
# 89    2985       1
# 90    2810       1
#
# [75 rows x 26 columns]

# %% [markdown]
# **Problem-3 (v)**
#
# ---

# %%
df.dtypes
# Out:
# Manufacturer             int8
# Model                    int8
# Type                     int8
# Min.Price             float64
# Price                 float64
# Max.Price             float64
# MPG.city                int64
# MPG.highway             int64
# AirBags                  int8
# DriveTrain               int8
# Cylinders                int8
# EngineSize            float64
# Horsepower              int64
# RPM                     int64
# Rev.per.mile            int64
# Man.trans.avail          int8
# Fuel.tank.capacity    float64
# Passengers              int64
# Length                  int64
# Wheelbase               int64
# Width                   int64
# Turn.circle             int64
# Rear.seat.room        float64
# Luggage.room          float64
# Weight                  int64
# Origin                   int8
# dtype: object

# %%
for col in col_list:
  if col not in obj_list:
    df[col] = (df[col] - df[col].mean()) / df[col].std()

# %%
df
# Out:
#     Manufacturer  Model  Type  Min.Price     Price  Max.Price  MPG.city  \
# 0              0     36     3  -0.396535 -0.281831  -0.189063  0.318063
# 1              0     43     2   1.419061  1.531668   1.569048 -0.900793
# 4              1      2     2   0.806437  1.138743   1.348180 -0.204304
# 5              2     13     2  -0.251733 -0.301981  -0.321584 -0.204304
# 6              2     41     1   0.383169  0.211844   0.067144 -0.726671
# ..           ...    ...   ...        ...       ...        ...       ...
# 84            27     12     4  -0.251733 -0.029956   0.146657  0.318063
# 85            27      8     2  -0.140347 -0.050106   0.022970 -0.204304
# 87            28     33     3  -0.864358 -0.966931  -1.010693  0.318063
# 89            28     50     0   0.126980  0.131244   0.128987 -0.378426
# 90            28     18     4   0.717328  0.463719   0.243839 -0.900793
#
#     MPG.highway  AirBags  DriveTrain  ...  Fuel.tank.capacity  Passengers  \
# 0      0.188818        2           1  ...           -0.926750    0.092227
# 1     -0.991294        0           1  ...            0.650697    0.092227
# 4     -0.007867        1           2  ...            1.669465   -1.291173
# 5      0.188818        1           1  ...            0.124881    1.475626
# 6     -0.401238        1           1  ...            0.650697    1.475626
# ..          ...      ...         ...  ...                 ...         ...
# 84     0.385503        1           1  ...           -0.039436   -1.291173
# 85    -0.204553        1           1  ...            0.815014    0.092227
# 87     0.582189        2           1  ...           -1.189658   -1.291173
# 89    -0.007867        2           1  ...            0.815014    0.092227
# 90    -0.991294        2           1  ...            0.815014   -1.291173
#
#       Length  Wheelbase     Width  Turn.circle  Rear.seat.room  Luggage.room  \
# 0  -0.393465  -0.193160 -0.261277    -0.543610       -0.316434     -0.902680
# 1   0.748852   1.748399  0.522554    -0.234741        0.887391      0.386863
# 4   0.177694   0.852295  0.000000     0.074129       -0.144459     -0.257909
# 5   0.368080   0.254892  0.000000     0.691867        0.199491      0.709249
# 6   1.066162   1.150996  1.306385     1.000736        1.059366      1.031634
# ..       ...        ...       ...          ...             ...           ...
# 84 -0.583851  -0.641212  0.000000     0.074129       -1.520259     -0.257909
# 85  0.304618  -0.043810  0.261277    -0.234741        0.371466      0.386863
# 87 -1.281933  -1.537317 -1.567662    -1.470217       -0.488409     -1.225066
# 89 -0.203079  -0.043810 -0.522554    -1.161348        1.403316      0.064477
# 90 -1.535781  -0.939914 -0.783831    -0.852479       -0.488409      0.386863
#
#       Weight  Origin
# 0  -0.482797       1
# 1   0.986213       1
# 4   1.123664       1
# 5  -0.182123       0
# 6   0.831580       0
# ..       ...     ...
# 84 -0.061853       1
# 85  0.075598       1
# 87 -1.281733       1
# 89 -0.001718       1
# 90 -0.302393       1
#
# [75 rows x 26 columns]

# %% [markdown]
# **Problem-3 (vi)**
#
# ---

# %%
train, val, test = np.split(df.sample(frac=1), [int(0.7 * len(df)), int(0.9 * len(df))])

# %%
train
# Out:
#     Manufacturer  Model  Type  Min.Price     Price  Max.Price  MPG.city  \
# 85            27      8     2  -0.140347 -0.050106   0.022970 -0.204304
# 68            21     22     2  -0.251733 -0.241531  -0.224402 -0.030181
# 83            27     72     3  -0.964605 -0.896406  -0.807494  1.536920
# 73            23     68     0  -0.786387 -0.765431  -0.719147 -0.030181
# 63            20     60     3  -0.864358 -0.694906  -0.533618  1.014553
# 28             8     67     3  -0.953467 -0.654606  -0.392262  1.014553
# 23             7     62     3  -0.897774 -0.745281  -0.595461 -0.030181
# 11             4     11     0  -0.886635 -0.533706  -0.233237  0.318063
# 89            28     50     0   0.126980  0.131244   0.128987 -0.378426
# 50            15     17     2   1.875745  1.571968   1.268667 -1.074915
# 29             8     74     1   0.115842  0.060719   0.022970 -0.552548
# 75            23     34     2  -0.118069 -0.019881   0.058309 -0.726671
# 7              2     56     1   0.683912  0.504019   0.349855 -1.249038
# 53            16     53     3  -0.619308 -0.715056  -0.763321  0.840431
# 59            18      9     4  -0.351981 -0.463181  -0.524783 -0.030181
# 72            23     40     3  -0.920051 -0.977006  -0.975354  1.362798
# 33             9     49     4  -0.630446 -0.281831   0.005301 -0.204304
# 9              3     23     1   1.842329  1.612268   1.357015 -1.249038
# 4              1      2     2   0.806437  1.138743   1.348180 -0.204304
# 51            15     73     1   1.998270  1.753318   1.489536 -0.900793
# 61            19     48     3  -0.975744 -0.846031  -0.710312  1.014553
# 14             4     45     2  -0.340842 -0.281831  -0.224402 -0.378426
# 8              2     55     2   1.096041  0.765969   0.473542 -0.726671
# 32             9     71     0  -0.675001 -0.745281  -0.772156 -0.204304
# 71            22     38     4  -0.563615 -0.432956  -0.312750 -0.030181
# 79            25     37     3  -1.020298 -1.037456  -1.010693  1.711042
# 49            14     57     2   2.031686  1.662643   1.295172 -0.900793
# 10             3     61     2   2.343568  2.156318   1.922438 -1.249038
# 36             9     70     2  -0.095792  0.151394   0.341021 -0.378426
# 22             7     15     3  -0.953467 -0.956856  -0.913511  1.014553
# 27             7     65     4   0.227228  0.715594   1.074303 -0.900793
# 17             4     10     1   0.171535  0.010344  -0.118385 -1.074915
# 44            12     28     3  -0.830942 -0.876256  -0.878172 -0.204304
# 40            11     51     4   0.060149  0.111094   0.155491  0.143941
# 46            12     63     2  -0.452228 -0.483331  -0.498279 -0.552548
# 0              0     36     3  -0.396535 -0.281831  -0.189063  0.318063
# 87            28     33     3  -0.864358 -0.966931  -1.010693  0.318063
# 66            20     46     2   0.505694  0.282369   0.093648 -0.378426
# 48            14     26     2   1.229705  0.937243   0.659071 -0.900793
# 42            11      3     0  -0.296288 -0.120631   0.022970  0.143941
# 58            17      1     2   3.045301  4.352668   5.217793 -0.726671
# 78            24     58     3  -0.808664 -0.765431  -0.710312  0.840431
# 39            10     66     4  -0.552476 -0.624381  -0.657304  1.188675
# 62            19     24     2   0.661635  0.745819   0.791592 -0.900793
# 5              2     13     2  -0.251733 -0.301981  -0.321584 -0.204304
# 20             6     39     0  -0.218317 -0.291906  -0.339254 -0.030181
# 12             4     19     0  -0.563615 -0.735206  -0.842833  0.318063
# 47            13     54     2   3.223519  2.942168   2.602712 -1.074915
# 31             9     29     3  -0.897774 -0.866181  -0.798660 -0.030181
# 41            11     14     3  -0.897774 -0.664681  -0.454105  3.278143
# 90            28     18     4   0.717328  0.463719   0.243839 -0.900793
# 84            27     12     4  -0.251733 -0.029956   0.146657  0.318063
#
#     MPG.highway  AirBags  DriveTrain  ...  Fuel.tank.capacity  Passengers  \
# 85    -0.204553        1           1  ...            0.815014    0.092227
# 68     0.188818        1           1  ...            0.157745    0.092227
# 83     1.368930        1           1  ...           -1.353975    0.092227
# 73     0.188818        2           1  ...           -0.269481    0.092227
# 63     0.582189        1           1  ...           -0.926750    0.092227
# 28     0.582189        2           1  ...           -0.926750    0.092227
# 23    -0.204553        1           1  ...           -0.663842    0.092227
# 11     1.172245        2           1  ...           -0.269481    0.092227
# 89    -0.007867        2           1  ...            0.815014    0.092227
# 50    -0.794609        0           1  ...            0.782151    1.475626
# 29    -0.401238        0           1  ...            0.650697    1.475626
# 75    -0.597923        2           1  ...            0.157745    0.092227
# 7     -0.991294        1           2  ...            2.293871    1.475626
# 53     1.172245        2           1  ...           -0.499525    0.092227
# 59    -0.794609        1           1  ...           -1.616883   -1.291173
# 72     2.155671        2           1  ...           -0.926750   -1.291173
# 33    -0.204553        1           2  ...           -0.203754   -1.291173
# 9     -0.991294        1           1  ...            0.650697    1.475626
# 4     -0.007867        1           2  ...            1.669465   -1.291173
# 51    -0.794609        0           2  ...            1.307966    1.475626
# 61     0.582189        2           1  ...           -0.926750    0.092227
# 14    -0.204553        2           1  ...            0.157745    1.475626
# 8     -0.597923        1           1  ...            0.913605    0.092227
# 32    -0.597923        2           1  ...           -0.039436    0.092227
# 71    -0.007867        2           0  ...           -0.039436   -1.291173
# 79     1.368930        2           0  ...           -2.241289   -1.291173
# 49    -1.384665        0           2  ...            1.505147   -1.291173
# 10    -0.991294        0           1  ...            1.307966    0.092227
# 36    -0.007867        1           1  ...           -0.006573    0.092227
# 22     0.582189        2           1  ...           -0.926750    0.092227
# 27    -1.187979        1           0  ...            1.242239   -1.291173
# 17    -0.794609        1           2  ...            2.293871    1.475626
# 44    -0.204553        2           1  ...           -0.762433    0.092227
# 40     0.188818        0           1  ...           -0.039436   -1.291173
# 46    -0.597923        2           1  ...            0.387789    0.092227
# 0      0.188818        2           1  ...           -0.926750    0.092227
# 87     0.582189        2           1  ...           -1.189658   -1.291173
# 66    -0.794609        1           1  ...            0.815014    0.092227
# 48    -1.187979        1           1  ...            0.815014    0.092227
# 42     0.188818        0           1  ...            0.322062   -1.291173
# 58    -0.991294        0           2  ...            0.815014    0.092227
# 78     1.565615        1           1  ...           -1.058204    0.092227
# 39     1.172245        1           1  ...           -1.189658   -1.291173
# 62    -1.187979        1           1  ...            0.979332    0.092227
# 5      0.188818        1           1  ...            0.124881    1.475626
# 20    -0.401238        0           1  ...           -0.006573    1.475626
# 12     0.778874        1           1  ...           -0.138027    0.092227
# 21             6     35     1   1.452477  1.088368   0.756253 -0.552548
# 45            12     59     4  -0.819803 -0.876256  -0.878172  0.492186
# 74            23     32     4  -0.274010 -0.100481   0.040640 -0.726671
# 64            20      5     0  -0.385397 -0.301981  -0.233237  0.143941
#
#     MPG.highway  AirBags  DriveTrain  ...  Fuel.tank.capacity  Passengers  \
# 80    -0.007867        2           0  ...           -0.039436    0.092227
# 57    -0.204553        1           2  ...           -0.499525    0.092227
# 34    -0.007867        1           1  ...           -0.170890   -1.291173
# 67     0.188818        2           1  ...           -0.269481    0.092227
# 21    -0.794609        1           1  ...           -0.006573    1.475626
# 45     0.778874        2           1  ...           -1.353975   -1.291173
# 74    -0.401238        0           2  ...           -0.170890   -1.291173
# 64    -0.007867        1           1  ...           -0.039436    0.092227
#
#       Length  Wheelbase     Width  Turn.circle  Rear.seat.room  Luggage.room  \
# 80 -0.520389  -0.939914 -1.045108    -1.161348        0.027516      0.386863
# 57 -0.520389   0.254892 -0.522554    -1.470217       -0.488409     -0.580294
# 34 -0.266541  -0.043810  0.261277    -0.234741       -1.520259      1.354020
# 67  0.304618  -0.043810 -0.522554     0.074129        0.199491      0.064477
# 21  1.256548   1.001646  0.000000     1.618474        2.951091      1.031634
# 45 -1.091547  -1.387966 -1.306385    -1.470217       -1.348284     -1.547452
# 74  0.812314  -0.342511  1.567662     1.309605       -0.832359     -0.257909
# 64 -0.139616  -0.043810 -0.522554     0.382998        0.371466      0.064477
#
#       Weight  Origin
# 80 -0.852198       1
# 57 -0.113397       1
# 34 -0.474207       0
# 67 -0.130579       0
# 21  1.003394       0
# 45 -1.204416       1
# 74  0.436408       0
# 64  0.109961       1
#
# [8 rows x 26 columns]

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# # Problem-4
#
# ---

# %% [markdown]
# **Problem-4 (a)**
#
# ---

# %%
x = np.linspace(-10, 10, 1000)
y = 5*x + 4

plt.plot(x, y)
plt.show()

# %% [markdown]
# **Problem-4 (b)**
#
# ---

# %%
x = np.linspace(10, 1000, 100)
y = np.log(x)

plt.plot(x, y)
plt.plot([10, 1000], np.log([10, 1000]), 'o')
plt.show()

# %% [markdown]
# **Problem-4 (c)**
#
# ---

# %%
x = np.linspace(-10, 10, 100)
y = x**2

plt.plot(x, y)
plt.show()

# %% [markdown]
# **Problem-4 (d)**
#
# ---

# %%
x = [0, 1, 2, 3, 4]
y = [2, 3, 4, 5, 6]

plt.plot(x, y)
plt.show()

# %% [markdown]
# # Problem-5

# %% [markdown]
# **Import the Necessary Python Libraries and Components**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split as tts
from sklearn.linear_model import LogisticRegression as LR
from sklearn.tree import DecisionTreeClassifier as DTC
from sklearn.metrics import confusion_matrix as cm
from sklearn.metrics import precision_score as ps
from sklearn.metrics import recall_score as rs
from sklearn.metrics import f1_score as f1s
from sklearn.metrics import accuracy_score as acc

# %% [markdown]
# **To Disable Convergence Warnings (For Custom Training)**

# %%
from warnings import simplefilter
from sklearn.exceptions import ConvergenceWarning
simplefilter("ignore", category=ConvergenceWarning)

# %% [markdown]
# **1.) Input the Dataset**

# %%
# Dataset Reference :- https://www.kaggle.com/uciml/breast-cancer-wisconsin-data

data = pd.read_csv('/content/drive/MyDrive/PRML_Lab/Lab_1/Wisconsin_DataSet.csv')
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0    ...          17.33           184.60      2019.0           0.16220
# 1    ...          23.41           158.80      1956.0           0.12380
# 2    ...          25.53           152.50      1709.0           0.14440
# 3    ...          26.50            98.87       567.7           0.20980
# 4    ...          16.67           152.20      1575.0           0.13740
# ..   ...            ...              ...         ...               ...
# 564  ...          26.40           166.10      2027.0           0.14100
# 565  ...          38.25           155.00      1731.0           0.11660
# 566  ...          34.12           126.70      1124.0           0.11390
# 567  ...          39.42           184.60      1821.0           0.16500
# 568  ...          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.66560           0.7119                0.2654          0.4601
# 1              0.18660           0.2416                0.1860          0.2750
# 2              0.42450           0.4504                0.2430          0.3613
# 3              0.86630           0.6869                0.2575          0.6638
# 4              0.20500           0.4000                0.1625          0.2364
# ..                 ...              ...                   ...             ...
# 564            0.21130           0.4107                0.2216          0.2060
# 565            0.19220           0.3215                0.1628          0.2572
# 566            0.30940           0.3403                0.1418          0.2218
# 567            0.86810           0.9387                0.2650          0.4087
# 568            0.06444           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst  Unnamed: 32
# 0                    0.11890          NaN
# 1                    0.08902          NaN
# 2                    0.08758          NaN
# 3                    0.17300          NaN
# 4                    0.07678          NaN
# ..                       ...          ...
# 564                  0.07115          NaN
# 565                  0.06637          NaN
# 566                  0.07820          NaN
# 567                  0.12400          NaN
# 568                  0.07039          NaN
#
# [569 rows x 33 columns]

# %% [markdown]
# **2.) Convert the String Labels into easily-interpretable Numerics**

# %%
# Note :- There are many existing Encoders for converting String to Numeric Labels, but for convenience, we used Pandas.

condition_M = data.diagnosis == "M"
condition_B = data.diagnosis == "B"

data.loc[condition_M,"diagnosis"]=0
data.loc[condition_B,"diagnosis"]=1

data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         0        17.99         10.38          122.80     1001.0
# 1      842517         0        20.57         17.77          132.90     1326.0
# 2    84300903         0        19.69         21.25          130.00     1203.0
# 3    84348301         0        11.42         20.38           77.58      386.1
# 4    84358402         0        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         0        21.56         22.39          142.00     1479.0
# 565    926682         0        20.13         28.25          131.20     1261.0
# 566    926954         0        16.60         28.08          108.30      858.1
# 567    927241         0        20.60         29.33          140.10     1265.0
# 568     92751         1         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0    ...          17.33           184.60      2019.0           0.16220
# 1    ...          23.41           158.80      1956.0           0.12380
# 2    ...          25.53           152.50      1709.0           0.14440
# 3    ...          26.50            98.87       567.7           0.20980
# 4    ...          16.67           152.20      1575.0           0.13740
# ..   ...            ...              ...         ...               ...
# 564  ...          26.40           166.10      2027.0           0.14100
# 565  ...          38.25           155.00      1731.0           0.11660
# 566  ...          34.12           126.70      1124.0           0.11390
# 567  ...          39.42           184.60      1821.0           0.16500
# 568  ...          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.66560           0.7119                0.2654          0.4601
# 1              0.18660           0.2416                0.1860          0.2750
# 2              0.42450           0.4504                0.2430          0.3613
# 3              0.86630           0.6869                0.2575          0.6638
# 4              0.20500           0.4000                0.1625          0.2364
# ..                 ...              ...                   ...             ...
# 564            0.21130           0.4107                0.2216          0.2060
# 565            0.19220           0.3215                0.1628          0.2572
# 566            0.30940           0.3403                0.1418          0.2218
# 567            0.86810           0.9387                0.2650          0.4087
# 568            0.06444           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst  Unnamed: 32
# 0                    0.11890          NaN
# 1                    0.08902          NaN
# 2                    0.08758          NaN
# 3                    0.17300          NaN
# 4                    0.07678          NaN
# ..                       ...          ...
# 564                  0.07115          NaN
# 565                  0.06637          NaN
# 566                  0.07820          NaN
# 567                  0.12400          NaN
# 568                  0.07039          NaN
#
# [569 rows x 33 columns]

# %% [markdown]
# **3.) Converting Dataframe into Numpy Arrays (Features and Labels)**

# %%
Y = data.diagnosis.to_numpy().astype('int')                                     # Labels

X_data = data.drop(columns=["id","diagnosis","Unnamed: 32"])
X = X_data.to_numpy()                                                           # Input Features

# %% [markdown]
# **4.) Splitting the Dataset into Train and Test Portions**

# %%
user_prompt = 0.3
user_enable = False

x_train,x_test,y_train,y_test = tts(X,Y,test_size=user_prompt,shuffle=user_enable)

# %% [markdown]
# **5.) Model Training and Predicting**

# %%
# Note :- Don't worry about the code snippet here, it is just to produce the predictions for the test data portion of each classifier

logistic_model = LR()
logistic_model.fit(x_train,y_train)
logistic_pred = logistic_model.predict(x_test)

decision_model = DTC()
decision_model.fit(x_train,y_train)
decision_pred = decision_model.predict(x_test)

# %% [markdown]
# **6.) Evaluation Metrics (Inbulit v/s Scaratch)**

# %% [markdown]
# ## Confusion Matrix

# %%
inbuilt_matrix_logistic = cm(y_test,logistic_pred)
inbuilt_matrix_decision = cm(y_test,decision_pred)

print("Confusion Matrix for Logistic Regression-based Predictions =>")
print(inbuilt_matrix_logistic)
print("Confusion Matrix for Decision Tree-based Predictions =>")
print(inbuilt_matrix_decision)

def confusion_matrix(y_test, y_pred):    
  true_pos = 0
  true_neg = 0
  false_pos = 0
  false_neg = 0

  for i in range(len(y_test)):
    if y_test[i] == 1 and y_pred[i] == 1:
      true_pos += 1
    elif y_test[i] == 0 and y_pred[i] == 0:
      true_neg += 1
    elif y_test[i] == 1 and y_pred[i] == 0:
      false_neg += 1
    elif y_test[i] == 0 and y_pred[i] == 1:
      false_pos += 1

  return np.array([[true_neg, false_pos], [false_neg, true_pos]])
# Out:
# Confusion Matrix for Logistic Regression-based Predictions =>
# [[ 38   1]
#  [ 11 121]]
# Confusion Matrix for Decision Tree-based Predictions =>
# [[ 38   1]
#  [ 24 108]]

# %% [markdown]
# ## Average Accuracy

# %%
inbuilt_acc_logistic = acc(y_test,logistic_pred)
inbuilt_acc_decision = acc(y_test,decision_pred)

print("Accuracy for Logistic Regression-based Predictions =>",str(inbuilt_acc_logistic*100)+"%")
print("Accuracy for Decision Tree-based Predictions =>",str(inbuilt_acc_decision*100)+"%")

def avg_accuracy(y_test, y_pred):
  true_pos = 0
  true_neg = 0

  for i in range(len(y_test)):
    if y_test[i] == 1 and y_pred[i] == 1:
      true_pos += 1
    elif y_test[i] == 0 and y_pred[i] == 0:
      true_neg += 1

  return (true_pos + true_neg) / len(y_test)
# Out:
# Accuracy for Logistic Regression-based Predictions => 92.98245614035088%
# Accuracy for Decision Tree-based Predictions => 85.38011695906432%

# %% [markdown]
# ## Precision

# %%
inbuilt_ps_logistic = ps(y_test,logistic_pred)
inbuilt_ps_decision = ps(y_test,decision_pred)

print("Precision for Logistic Regression-based Predictions =>",str(inbuilt_ps_logistic*100)+"%")
print("Precision for Decision Tree-based Predictions =>",str(inbuilt_ps_decision*100)+"%")

def precision(y_test, y_pred):
  true_pos = 0
  false_pos = 0

  for i in range(len(y_test)):
    if y_test[i] == 1 and y_pred[i] == 1:
      true_pos += 1
    elif y_test[i] == 0 and y_pred[i] == 1:
      false_pos += 1

  return true_pos / (true_pos + false_pos)
# Out:
# Precision for Logistic Regression-based Predictions => 99.18032786885246%
# Precision for Decision Tree-based Predictions => 99.08256880733946%

# %% [markdown]
# ## Recall

# %%
inbuilt_rs_logistic = rs(y_test,logistic_pred)
inbuilt_rs_decision = rs(y_test,decision_pred)

print("Recall for Logistic Regression-based Predictions =>",str(inbuilt_rs_logistic*100)+"%")
print("Recall for Decision Tree-based Predictions =>",str(inbuilt_rs_decision*100)+"%")

def recall(y_test, y_pred):
  true_pos = 0
  false_neg = 0

  for i in range(len(y_test)):
    if y_test[i] == 1 and y_pred[i] == 1:
      true_pos += 1
    elif y_test[i] == 1 and y_pred[i] == 0:
      false_neg += 1

  return true_pos / (true_pos + false_neg)
# Out:
# Recall for Logistic Regression-based Predictions => 91.66666666666666%
# Recall for Decision Tree-based Predictions => 81.81818181818183%

# %% [markdown]
# ## F-1 Score

# %%
inbuilt_f1s_logistic = f1s(y_test,logistic_pred)
inbuilt_f1s_decision = f1s(y_test,decision_pred)

print("F1-Score for Logistic Regression-based Predictions =>",str(inbuilt_f1s_logistic*100)+"%")
print("F1-Score for Decision Tree-based Predictions =>",str(inbuilt_f1s_decision*100)+"%")

def f1_score(y_test, y_pred):
  prec = precision(y_test, y_pred)
  rec = recall (y_test, y_pred)

  return 2 * prec * rec / (prec + rec)
# Out:
# F1-Score for Logistic Regression-based Predictions => 95.2755905511811%
# F1-Score for Decision Tree-based Predictions => 89.62655601659752%

# %% [markdown]
# ## Class-Wise Accuracy

# %%
def class_accuracy(y_test, y_pred):
  true_pos = 0
  true_neg = 0
  false_pos = 0
  false_neg = 0

  for i in range(len(y_test)):
    if y_test[i] == 1 and y_pred[i] == 1:
      true_pos += 1
    elif y_test[i] == 0 and y_pred[i] == 0:
      true_neg += 1
    elif y_test[i] == 1 and y_pred[i] == 0:
      false_neg += 1
    elif y_test[i] == 0 and y_pred[i] == 1:
      false_pos += 1

  return 0.5 * (( true_pos / (true_pos + false_neg) + ( true_neg / (true_neg + false_pos) )))

# %% [markdown]
# ## Sensitivity

# %%
def sensitivity(y_test, y_pred):
    return recall(y_test, y_pred)

# %% [markdown]
# ## Specificity

# %%
def specificity(y_test, y_pred):
  true_neg = 0
  false_pos = 0

  for i in range(len(y_test)):
    if y_test[i] == 0 and y_pred[i] == 0:
      true_neg += 1
    elif y_test[i] == 0 and y_pred[i] == 1:
      false_pos += 1

  return true_neg / (true_neg + false_pos)
